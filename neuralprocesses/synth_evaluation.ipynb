# %%
import numpy as np
import numpy.random as npr
import torch
import torch.nn as nn
import torch.optim as optim
import collections
import matplotlib.pyplot as plt
import gc
import datetime
import os
import sys
import time
import warnings
from functools import partial
import experiment as exp
import lab as B
import wbml.out as out
from matrix.util import ToDenseWarning
from wbml.experiment import WorkingDirectory
import neuralprocesses.torch as nps
from neuralprocesses.numdata import num_data

os.environ["KMP_DUPLICATE_LIB_OK"] = "True"

# %%
class mydict(dict):
    def __getattribute__(self, key):
        if key in self:
            return self[key]
        else:
            return super().__getattribute__(key) 
        
        
def get_dir(args, suffix, observe, seed, model_name, dim_x, dim_y):
    wd = WorkingDirectory(
        *args.root,
        *(args.subdir or ()),
        args.data,
        *((f"x{dim_x}_y{dim_y}",) if hasattr(args, "dim_x") else ()),
        model_name,
        *((args.arch,) if hasattr(args, "arch") else ()),
        args.objective,
        str(seed),
        log=f"log{suffix}.txt",
        diff=f"diff{suffix}.txt",
        observe=observe,
    )
    return wd

        
def construct_model(name):
    if name == "cnp":
        model = nps.construct_gnp(
            dim_x=config["dim_x"],
            dim_yc=(1,) * config["dim_y"],
            dim_yt=config["dim_y"],
            dim_embedding=config["dim_embedding"],
            enc_same=config["enc_same"],
            num_dec_layers=config["num_layers"],
            width=config["width"],
            likelihood="het",
            transform=config["transform"],
        )
    elif name == "rcnp":
        model = nps.construct_rnp(
            dim_x=config["dim_x"],
            dim_yc=(1,) * config["dim_y"],
            dim_yt=config["dim_y"],
            dim_embedding=config["dim_embedding"],
            enc_same=config["enc_same"],
            num_dec_layers=config["num_layers"],
            width=config["width"],
            relational_width=config['relational_width'],
            num_relational_enc_layers=config['num_relational_layers'],
            likelihood="het",
            transform=config["transform"],
        )
    elif name == "rgnp":
        model = nps.construct_rnp(
            dim_x=config["dim_x"],
            dim_yc=(1,) * config["dim_y"],
            dim_yt=config["dim_y"],
            dim_embedding=config["dim_embedding"],
            enc_same=config["enc_same"],
            num_dec_layers=config["num_layers"],
            width=config["width"],
            relational_width=config['relational_width'],
            num_relational_enc_layers=config['num_relational_layers'],
            likelihood="lowrank",
            transform=config["transform"],
        )
    elif name == "gnp":
        model = nps.construct_gnp(
            dim_x=config["dim_x"],
            dim_yc=(1,) * config["dim_y"],
            dim_yt=config["dim_y"],
            dim_embedding=config["dim_embedding"],
            enc_same=config["enc_same"],
            num_dec_layers=config["num_layers"],
            width=config["width"],
            likelihood="lowrank",
            num_basis_functions=config["num_basis_functions"],
            transform=config["transform"],
        )
        
    return model

# %%
config = {
        "default": {
            "epochs": None,
            "rate": None,
            "also_ar": False,
        },
        "epsilon": 1e-8,
        "epsilon_start": 1e-2,
        "cholesky_retry_factor": 1e6,
        "fix_noise": None,
        "fix_noise_epochs": 3,
        "width": 256,
        "dim_embedding": 256,
        "relational_width": 64,
        "dim_relational_embeddings": 128,
        "enc_same": False,
        "num_heads": 8,
        "num_layers": 6,
        "num_relational_layers": 3,
        "unet_channels": (64,) * 6,
        "unet_strides": (1,) + (2,) * 5,
        "conv_channels": 64,
        "encoder_scales": None,
        "fullconvgnp_kernel_factor": 2,
        "mean_diff": 0,
        "num_basis_functions": 64,
    }

args = {"dim_x": 1,
        "dim_y": 1,
        "data": 'eq',
        "batch_size": 16,
        "epochs": 100,
        "rate": 3e-4,
        "objective": "loglik",
        "num_samples": 20,
        "unnormalised": False,
        "evaluate_num_samples": 512,
        "evaluate_batch_size": 8,
        "evaluate_num_plots": 5,
        "train_fast": True,
        "evaluate_fast": False,
        "seed": 1,
        "root": ["_experiments"],
        "subdir": None,
       }

# %%
args = mydict(args)

B.epsilon = config['epsilon']

# device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
device = torch.device("cpu")
B.set_global_device(device)
print(device)



suffix = "_evaluate"
observe = True
# Out:
# cpu

# %%
# data generation
def get_gen_eval(args, config):
    _, _, gens_eval = exp.data[args.data]["setup"](
            args,
            config,
            num_tasks_train=2**6 if args.train_fast else 2**14,
            num_tasks_cv=2**6 if args.train_fast else 2**12,
            num_tasks_eval=2**6 if args.evaluate_fast else 2**12,
            device=device,
        )
    return gens_eval


# define objective
objective_eval = partial(nps.loglik,
                         num_samples=args.evaluate_num_samples,
                         batch_size=args.evaluate_batch_size,
                         normalise=not args.unnormalised)

# %%
def eval(state, model, objective, gen):
    """Perform evaluation."""
    with torch.no_grad():
        vals, kls, kls_diag = [], [], []
        for batch in gen.epoch():
            state, obj = objective(
                state,
                model,
                batch["contexts"],
                batch["xt"],
                batch["yt"],
            )

            # Save numbers.
            n = nps.num_data(batch["xt"], batch["yt"])
            
            vals.append(B.to_numpy(obj))
            if "pred_logpdf" in batch:
                kls.append(B.to_numpy(batch["pred_logpdf"] / n - obj))
            if "pred_logpdf_diag" in batch:
                kls_diag.append(B.to_numpy(batch["pred_logpdf_diag"] / n - obj))
        print(vals)
        # Report numbers.
        vals = B.concat(*vals)
        kl = B.concat(*kls)
        kl_diag = B.concat(*kls_diag)

        out.kv("Loglik (V)", B.mean(vals))
        if kls:
            out.kv("KL (full)", B.mean(kl))
        if kls_diag:
            out.kv("KL (diag)", B.mean(kl_diag))

        return state, B.mean(vals), B.mean(kl), B.mean(kl_diag)

# %% [markdown]
# # Trivial

# %%
def eval_trivial(state, gen):
    """Perform evaluation."""
    with torch.no_grad():
        vals, kls, kls_diag = [], [], []
        for batch in gen.epoch():
            if batch['contexts'][0][1].shape[2] <= 5:
                continue
            m = torch.mean(batch['contexts'][0][1], dim=-1).squeeze()
            std = torch.std(batch['contexts'][0][1], dim=-1).squeeze()

            batch_size = len(m)
            
            n = nps.num_data(batch["xt"], batch["yt"])
            
            val = torch.zeros(batch_size)
            kl = torch.zeros(batch_size)
            kl_diag = torch.zeros(batch_size)
            for i in range(batch_size):
                dist = torch.distributions.normal.Normal(m[i], std[i])
                obj = torch.mean(dist.log_prob(batch['yt'][i].reshape(-1)))
                val[i] = obj
                
                kl[i] = batch['pred_logpdf'][i] / n[i] - obj
#                 print(obj)
                kl_diag[i] = batch['pred_logpdf_diag'][i] / n[i] - obj
                
            
            vals.append(B.to_numpy(val))
            if "pred_logpdf" in batch:
                kls.append(B.to_numpy(kl))
            if "pred_logpdf_diag" in batch:
                kls_diag.append(B.to_numpy(kl_diag))

        # Report numbers.
        vals = B.concat(*vals)
        kl = B.concat(*kls)
        kl_diag = B.concat(*kls_diag)

        out.kv("Loglik (V)", B.mean(vals))
        if kls:
            out.kv("KL (full)", B.mean(kl))
        if kls_diag:
            out.kv("KL (diag)", B.mean(kl_diag))

        return state, B.mean(vals), B.mean(kl), B.mean(kl_diag)

# %%
num_replicates = 1
args['dim_x'] = 5
gens_eval = get_gen_eval(args, config)

with out.Section(f"Evaluate on Trivial"):
    # 3 datasets, 3 metrics, num_replicates data
    results = np.zeros((3, 3, num_replicates))
    for seed in range(1, 1+num_replicates):
        with out.Section(f"Seed = {seed}"):
            state = B.create_random_state(torch.float32, seed=seed)

            for i, (gen_name, gen) in enumerate(gens_eval()):
                with out.Section(gen_name.capitalize()):
                    state, results[i, 0, seed-1], results[i, 1, seed-1], results[i, 2, seed-1] = eval_trivial(state, gen)

    with out.Section(f"Statistics over {num_replicates} replicates"):
        for i, (gen_name, _) in enumerate(gens_eval()):
            with out.Section(gen_name.capitalize()):
                out.kv("Loglik (V)", exp.with_err(results[i, 0]))
                out.kv("KL (full)", exp.with_err(results[i, 1]))
                out.kv("KL (diag)", exp.with_err(results[i, 2]))
# Out:
# Evaluate on Trivial:
#     Seed = 1:
#         Interpolation in training range:
#             Loglik (V): -1.472
#             KL (full):  0.0858
#             KL (diag):  0.05125
#         Interpolation beyond training range:
#             Loglik (V): -1.472
#             KL (full):  0.0858
#             KL (diag):  0.05125
#         Extrapolation beyond training range:
#             Loglik (V): -1.476
#             KL (full):  0.06804
#             KL (diag):  0.03124
#     Statistics over 1 replicates:
#         Interpolation in training range:
#             Loglik (V):   -1.47219 +-    0.00000
#             KL (full):     0.08580 +-    0.00000
#             KL (diag):     0.05125 +-    0.00000
#         Interpolation beyond training range:
#             Loglik (V):   -1.47219 +-    0.00000
#             KL (full):     0.08580 +-    0.00000
#             KL (diag):     0.05125 +-    0.00000
#         Extrapolation beyond training range:
#             Loglik (V):   -1.47550 +-    0.00000
#             KL (full):     0.06804 +-    0.00000
#             KL (diag):     0.03124 +-    0.00000

# %% [markdown]
# # dim_x = 2

# %%
model_list = ["cnp", "rcnp", "gnp", "rgnp"]  
num_replicates = 5
args['dim_x'] = 2
gens_eval = get_gen_eval(args, config)

for model_name in model_list:
    with out.Section(f"Evaluate on {model_name}"):
        # 3 datasets, 3 metrics, num_replicates data
        results = np.zeros((3, 3, num_replicates))
        for seed in range(1, 1+num_replicates):
            with out.Section(f"Seed = {seed}"):
                state = B.create_random_state(torch.float32, seed=seed)
                
                wd = get_dir(args, suffix, observe, seed, model_name, args.dim_x, args.dim_y)
                
                model = construct_model(model_name).to(device)
                name = "model-best.torch"
                model.load_state_dict(
                    torch.load(wd.file(name), map_location=device)["weights"]
                )

                for i, (gen_name, gen) in enumerate(gens_eval()):
                    with out.Section(gen_name.capitalize()):
                        state, results[i, 0, seed-1], results[i, 1, seed-1], results[i, 2, seed-1] = eval(state, model, objective_eval, gen)

        with out.Section(f"Statistics over {num_replicates} replicates"):
            for i, (gen_name, _) in enumerate(gens_eval()):
                with out.Section(gen_name.capitalize()):
                    out.kv("Loglik (V)", exp.with_err(results[i, 0]))
                    out.kv("KL (full)", exp.with_err(results[i, 1]))
                    out.kv("KL (diag)", exp.with_err(results[i, 2]))

# %% [markdown]
# # dim_x = 3

# %%
model_list = ["cnp", "rcnp", "gnp", "rgnp"]  
num_replicates = 5
args['dim_x'] = 3
gens_eval = get_gen_eval(args, config)

for model_name in model_list:
    with out.Section(f"Evaluate on {model_name}"):
        # 3 datasets, 3 metrics, num_replicates data
        results = np.zeros((3, 3, num_replicates))
        for seed in range(1, 1+num_replicates):
            with out.Section(f"Seed = {seed}"):
                state = B.create_random_state(torch.float32, seed=seed)
                
                wd = get_dir(args, suffix, observe, seed, model_name, args.dim_x, args.dim_y)
                
                model = construct_model(model_name).to(device)
                name = "model-best.torch"
                model.load_state_dict(
                    torch.load(wd.file(name), map_location=device)["weights"]
                )

                for i, (gen_name, gen) in enumerate(gens_eval()):
                    with out.Section(gen_name.capitalize()):
                        state, results[i, 0, seed-1], results[i, 1, seed-1], results[i, 2, seed-1] = eval(state, model, objective_eval, gen)

        with out.Section(f"Statistics over {num_replicates} replicates"):
            for i, (gen_name, _) in enumerate(gens_eval()):
                with out.Section(gen_name.capitalize()):
                    out.kv("Loglik (V)", exp.with_err(results[i, 0]))
                    out.kv("KL (full)", exp.with_err(results[i, 1]))
                    out.kv("KL (diag)", exp.with_err(results[i, 2]))
# Out:
# Evaluate on cnp:
#     Seed = 1:
#         Interpolation in training range:
#             Loglik (V): -1.387
#             KL (full):  0.2612
#             KL (diag):  0.07966
#         Interpolation beyond training range:
#             Loglik (V): -1.496
#             KL (full):  0.3706
#             KL (diag):  0.1891
#         Extrapolation beyond training range:
#             Loglik (V): -1.502
#             KL (full):  0.2696
#             KL (diag):  0.05809
#     Seed = 2:
#         Interpolation in training range:
#             Loglik (V): -1.386
#             KL (full):  0.2598
#             KL (diag):  0.07831
#         Interpolation beyond training range:
#             Loglik (V): -1.47
#             KL (full):  0.3439
#             KL (diag):  0.1625
#         Extrapolation beyond training range:
#             Loglik (V): -1.473
#             KL (full):  0.2407
#             KL (diag):  0.02915
#     Seed = 3:
#         Interpolation in training range:
#             Loglik (V): -1.387
#             KL (full):  0.2611
#             KL (diag):  0.07962
#         Interpolation beyond training range:
#             Loglik (V): -1.467
#             KL (full):  0.3414
#             KL (diag):  0.1599
#         Extrapolation beyond training range:
#             Loglik (V): -1.471
#             KL (full):  0.2388
#             KL (diag):  0.02728
#     Seed = 4:
#         Interpolation in training range:
#             Loglik (V): -1.387
#             KL (full):  0.2609
#             KL (diag):  0.07939
#         Interpolation beyond training range:
#             Loglik (V): -1.474
#             KL (full):  0.3479
#             KL (diag):  0.1664
#         Extrapolation beyond training range:
#             Loglik (V): -1.479
#             KL (full):  0.2467
#             KL (diag):  0.03513
#     Seed = 5:
#         Interpolation in training range:
#             Loglik (V): -1.387
#             KL (full):  0.261
#             KL (diag):  0.07953
#         Interpolation beyond training range:
#             Loglik (V): -1.486
#             KL (full):  0.3602
#             KL (diag):  0.1787
#         Extrapolation beyond training range:
#             Loglik (V): -1.49
#             KL (full):  0.2581
#             KL (diag):  0.04656
#     Statistics over 5 replicates:
#         Interpolation in training range:
#             Loglik (V):   -1.38671 +-    0.00044
#             KL (full):     0.26080 +-    0.00044
#             KL (diag):     0.07930 +-    0.00044
#         Interpolation beyond training range:
#             Loglik (V):   -1.47873 +-    0.00962
#             KL (full):     0.35282 +-    0.00962
#             KL (diag):     0.17132 +-    0.00962
#         Extrapolation beyond training range:
#             Loglik (V):   -1.48269 +-    0.01015
#             KL (full):     0.25080 +-    0.01015
#             KL (diag):     0.03924 +-    0.01015
# Evaluate on rcnp:
#     Seed = 1:
#         Interpolation in training range:
#             Loglik (V): -1.32
#             KL (full):  0.1942
#             KL (diag):  0.01266
#         Interpolation beyond training range:
#             Loglik (V): -1.32
#             KL (full):  0.1942
#             KL (diag):  0.01266
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.2117
#             KL (diag):  1.653e-04
#     Seed = 2:
#         Interpolation in training range:
#             Loglik (V): -1.32
#             KL (full):  0.1941
#             KL (diag):  0.01258
#         Interpolation beyond training range:
#             Loglik (V): -1.32
#             KL (full):  0.1941
#             KL (diag):  0.01258
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.2117
#             KL (diag):  1.252e-04
#     Seed = 3:
#         Interpolation in training range:
#             Loglik (V): -1.32
#             KL (full):  0.1941
#             KL (diag):  0.01262
#         Interpolation beyond training range:
#             Loglik (V): -1.32
#             KL (full):  0.1941
#             KL (diag):  0.01262
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.2118
#             KL (diag):  2.014e-04
#     Seed = 4:
#         Interpolation in training range:
#             Loglik (V): -1.32
#             KL (full):  0.194
#             KL (diag):  0.01255
#         Interpolation beyond training range:
#             Loglik (V): -1.32
#             KL (full):  0.194
#             KL (diag):  0.01255
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.2117
#             KL (diag):  1.087e-04
#     Seed = 5:
#         Interpolation in training range:
#             Loglik (V): -1.32
#             KL (full):  0.194
#             KL (diag):  0.01248
#         Interpolation beyond training range:
#             Loglik (V): -1.32
#             KL (full):  0.194
#             KL (diag):  0.01248
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.2118
#             KL (diag):  2.174e-04
#     Statistics over 5 replicates:
#         Interpolation in training range:
#             Loglik (V):   -1.31999 +-    0.00005
#             KL (full):     0.19407 +-    0.00005
#             KL (diag):     0.01258 +-    0.00005
#         Interpolation beyond training range:
#             Loglik (V):   -1.31999 +-    0.00005
#             KL (full):     0.19407 +-    0.00005
#             KL (diag):     0.01258 +-    0.00005
#         Extrapolation beyond training range:
#             Loglik (V):   -1.44361 +-    0.00004
#             KL (full):     0.21172 +-    0.00004
#             KL (diag):     0.00016 +-    0.00004
# Evaluate on gnp:
#     Seed = 1:
#         Interpolation in training range:
#             Loglik (V): -1.299
#             KL (full):  0.1732
#             KL (diag):  -8.275e-03
#         Interpolation beyond training range:
#             Loglik (V): -1.513
#             KL (full):  0.387
#             KL (diag):  0.2055
#         Extrapolation beyond training range:
#             Loglik (V): -1.515
#             KL (full):  0.2829
#             KL (diag):  0.07135
#     Seed = 2:
#         Interpolation in training range:
#             Loglik (V): -1.298
#             KL (full):  0.1717
#             KL (diag):  -9.828e-03
#         Interpolation beyond training range:
#             Loglik (V): -1.585
#             KL (full):  0.459
#             KL (diag):  0.2775
#         Extrapolation beyond training range:
#             Loglik (V): -1.589
#             KL (full):  0.3573
#             KL (diag):  0.1458
#     Seed = 3:
#         Interpolation in training range:
#             Loglik (V): -1.298
#             KL (full):  0.1725
#             KL (diag):  -9.008e-03
#         Interpolation beyond training range:
#             Loglik (V): -1.539
#             KL (full):  0.4126
#             KL (diag):  0.2311
#         Extrapolation beyond training range:
#             Loglik (V): -1.543
#             KL (full):  0.3111
#             KL (diag):  0.09956
#     Seed = 4:
#         Interpolation in training range:
#             Loglik (V): -1.297
#             KL (full):  0.1714
#             KL (diag):  -0.01005
#         Interpolation beyond training range:
#             Loglik (V): -1.561
#             KL (full):  0.4355
#             KL (diag):  0.254
#         Extrapolation beyond training range:
#             Loglik (V): -1.563
#             KL (full):  0.3312
#             KL (diag):  0.1196
#     Seed = 5:
#         Interpolation in training range:
#             Loglik (V): -1.297
#             KL (full):  0.1716
#             KL (diag):  -9.938e-03
#         Interpolation beyond training range:
#             Loglik (V): -1.515
#             KL (full):  0.3895
#             KL (diag):  0.208
#         Extrapolation beyond training range:
#             Loglik (V): -1.518
#             KL (full):  0.2865
#             KL (diag):  0.07492
#     Statistics over 5 replicates:
#         Interpolation in training range:
#             Loglik (V):   -1.29799 +-    0.00060
#             KL (full):     0.17208 +-    0.00060
#             KL (diag):    -0.00942 +-    0.00060
#         Interpolation beyond training range:
#             Loglik (V):   -1.54263 +-    0.02410
#             KL (full):     0.41671 +-    0.02410
#             KL (diag):     0.23522 +-    0.02410
#         Extrapolation beyond training range:
#             Loglik (V):   -1.54570 +-    0.02450
#             KL (full):     0.31381 +-    0.02450
#             KL (diag):     0.10225 +-    0.02450
# Evaluate on rgnp:
#     Seed = 1:
#         Interpolation in training range:
#             Loglik (V): -1.279
#             KL (full):  0.1532
#             KL (diag):  -0.02828
#         Interpolation beyond training range:
#             Loglik (V): -1.279
#             KL (full):  0.1532
#             KL (diag):  -0.02828
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.2124
#             KL (diag):  8.616e-04
#     Seed = 2:
#         Interpolation in training range:
#             Loglik (V): -1.285
#             KL (full):  0.1591
#             KL (diag):  -0.02244
#         Interpolation beyond training range:
#             Loglik (V): -1.285
#             KL (full):  0.1591
#             KL (diag):  -0.02244
#         Extrapolation beyond training range:
#             Loglik (V): -1.442
#             KL (full):  0.2103
#             KL (diag):  -1.306e-03
#     Seed = 3:
#         Interpolation in training range:
#             Loglik (V): -1.289
#             KL (full):  0.1631
#             KL (diag):  -0.01842
#         Interpolation beyond training range:
#             Loglik (V): -1.289
#             KL (full):  0.1631
#             KL (diag):  -0.01842
#         Extrapolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.2132
#             KL (diag):  1.600e-03
#     Seed = 4:
#         Interpolation in training range:
#             Loglik (V): -1.283
#             KL (full):  0.1572
#             KL (diag):  -0.02429
#         Interpolation beyond training range:
#             Loglik (V): -1.283
#             KL (full):  0.1572
#             KL (diag):  -0.02429
#         Extrapolation beyond training range:
#             Loglik (V): -1.442
#             KL (full):  0.2102
#             KL (diag):  -1.312e-03
#     Seed = 5:
#         Interpolation in training range:
#             Loglik (V): -1.291
#             KL (full):  0.1656
#             KL (diag):  -0.01593
#         Interpolation beyond training range:
#             Loglik (V): -1.291
#             KL (full):  0.1656
#             KL (diag):  -0.01593
#         Extrapolation beyond training range:
#             Loglik (V): -1.438
#             KL (full):  0.2059
#             KL (diag):  -5.656e-03
#     Statistics over 5 replicates:
#         Interpolation in training range:
#             Loglik (V):   -1.28554 +-    0.00381
#             KL (full):     0.15962 +-    0.00381
#             KL (diag):    -0.02187 +-    0.00381
#         Interpolation beyond training range:
#             Loglik (V):   -1.28554 +-    0.00381
#             KL (full):     0.15962 +-    0.00381
#             KL (diag):    -0.02187 +-    0.00381
#         Extrapolation beyond training range:
#             Loglik (V):   -1.44229 +-    0.00222
#             KL (full):     0.21040 +-    0.00222
#             KL (diag):    -0.00116 +-    0.00222

# %% [markdown]
# # dim_x = 4

# %%
model_list = ["cnp", "rcnp", "gnp", "rgnp"]  
num_replicates = 5
args['dim_x'] = 4
gens_eval = get_gen_eval(args, config)

for model_name in model_list:
    with out.Section(f"Evaluate on {model_name}"):
        # 3 datasets, 3 metrics, num_replicates data
        results = np.zeros((3, 3, num_replicates))
        for seed in range(1, 1+num_replicates):
            with out.Section(f"Seed = {seed}"):
                state = B.create_random_state(torch.float32, seed=seed)
                
                wd = get_dir(args, suffix, observe, seed, model_name, args.dim_x, args.dim_y)
                
                model = construct_model(model_name).to(device)
                name = "model-best.torch"
                model.load_state_dict(
                    torch.load(wd.file(name), map_location=device)["weights"]
                )

                for i, (gen_name, gen) in enumerate(gens_eval()):
                    with out.Section(gen_name.capitalize()):
                        state, results[i, 0, seed-1], results[i, 1, seed-1], results[i, 2, seed-1] = eval(state, model, objective_eval, gen)

        with out.Section(f"Statistics over {num_replicates} replicates"):
            for i, (gen_name, _) in enumerate(gens_eval()):
                with out.Section(gen_name.capitalize()):
                    out.kv("Loglik (V)", exp.with_err(results[i, 0]))
                    out.kv("KL (full)", exp.with_err(results[i, 1]))
                    out.kv("KL (diag)", exp.with_err(results[i, 2]))
# Out:
# Evaluate on cnp:
#     Seed = 1:
#         Interpolation in training range:
#             Loglik (V): -1.443
#             KL (full):  0.1295
#             KL (diag):  0.05153
#         Interpolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.131
#             KL (diag):  0.05304
#         Extrapolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.08619
#             KL (diag):  9.860e-04
#     Seed = 2:
#         Interpolation in training range:
#             Loglik (V): -1.443
#             KL (full):  0.1295
#             KL (diag):  0.05153
#         Interpolation beyond training range:
#             Loglik (V): -1.446
#             KL (full):  0.1318
#             KL (diag):  0.05387
#         Extrapolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.08607
#             KL (diag):  8.623e-04
#     Seed = 3:
#         Interpolation in training range:
#             Loglik (V): -1.443
#             KL (full):  0.1295
#             KL (diag):  0.05153
#         Interpolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.131
#             KL (diag):  0.05306
#         Extrapolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.08609
#             KL (diag):  8.871e-04
#     Seed = 4:
#         Interpolation in training range:
#             Loglik (V): -1.443
#             KL (full):  0.1295
#             KL (diag):  0.05152
#         Interpolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.1312
#             KL (diag):  0.05327
#         Extrapolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.08594
#             KL (diag):  7.324e-04
#     Seed = 5:
#         Interpolation in training range:
#             Loglik (V): -1.443
#             KL (full):  0.1295
#             KL (diag):  0.05154
#         Interpolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.131
#             KL (diag):  0.05307
#         Extrapolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.08614
#             KL (diag):  9.351e-04
#     Statistics over 5 replicates:
#         Interpolation in training range:
#             Loglik (V):   -1.44348 +-    0.00001
#             KL (full):     0.12950 +-    0.00001
#             KL (diag):     0.05153 +-    0.00001
#         Interpolation beyond training range:
#             Loglik (V):   -1.44521 +-    0.00028
#             KL (full):     0.13123 +-    0.00028
#             KL (diag):     0.05326 +-    0.00028
#         Extrapolation beyond training range:
#             Loglik (V):   -1.44520 +-    0.00007
#             KL (full):     0.08609 +-    0.00007
#             KL (diag):     0.00088 +-    0.00007
# Evaluate on rcnp:
#     Seed = 1:
#         Interpolation in training range:
#             Loglik (V): -1.395
#             KL (full):  0.0809
#             KL (diag):  2.931e-03
#         Interpolation beyond training range:
#             Loglik (V): -1.395
#             KL (full):  0.0809
#             KL (diag):  2.931e-03
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.08524
#             KL (diag):  3.733e-05
#     Seed = 2:
#         Interpolation in training range:
#             Loglik (V): -1.395
#             KL (full):  0.08085
#             KL (diag):  2.876e-03
#         Interpolation beyond training range:
#             Loglik (V): -1.395
#             KL (full):  0.08085
#             KL (diag):  2.876e-03
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.08527
#             KL (diag):  6.889e-05
#     Seed = 3:
#         Interpolation in training range:
#             Loglik (V): -1.395
#             KL (full):  0.08089
#             KL (diag):  2.917e-03
#         Interpolation beyond training range:
#             Loglik (V): -1.395
#             KL (full):  0.08089
#             KL (diag):  2.917e-03
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.08522
#             KL (diag):  1.812e-05
#     Seed = 4:
#         Interpolation in training range:
#             Loglik (V): -1.395
#             KL (full):  0.0809
#             KL (diag):  2.923e-03
#         Interpolation beyond training range:
#             Loglik (V): -1.395
#             KL (full):  0.0809
#             KL (diag):  2.923e-03
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.08522
#             KL (diag):  1.567e-05
#     Seed = 5:
#         Interpolation in training range:
#             Loglik (V): -1.395
#             KL (full):  0.08086
#             KL (diag):  2.884e-03
#         Interpolation beyond training range:
#             Loglik (V): -1.395
#             KL (full):  0.08086
#             KL (diag):  2.884e-03
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.08524
#             KL (diag):  3.141e-05
#     Statistics over 5 replicates:
#         Interpolation in training range:
#             Loglik (V):   -1.39486 +-    0.00002
#             KL (full):     0.08088 +-    0.00002
#             KL (diag):     0.00291 +-    0.00002
#         Interpolation beyond training range:
#             Loglik (V):   -1.39486 +-    0.00002
#             KL (full):     0.08088 +-    0.00002
#             KL (diag):     0.00291 +-    0.00002
#         Extrapolation beyond training range:
#             Loglik (V):   -1.44435 +-    0.00002
#             KL (full):     0.08524 +-    0.00002
#             KL (diag):     0.00003 +-    0.00002
# Evaluate on gnp:
#     Seed = 1:
#         Interpolation in training range:
#             Loglik (V): -1.443
#             KL (full):  0.1288
#             KL (diag):  0.05086
#         Interpolation beyond training range:
#             Loglik (V): -1.443
#             KL (full):  0.1294
#             KL (diag):  0.05146
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.08465
#             KL (diag):  -5.598e-04
#     Seed = 2:
#         Interpolation in training range:
#             Loglik (V): -1.418
#             KL (full):  0.104
#             KL (diag):  0.026
#         Interpolation beyond training range:
#             Loglik (V): -1.449
#             KL (full):  0.1346
#             KL (diag):  0.05665
#         Extrapolation beyond training range:
#             Loglik (V): -1.449
#             KL (full):  0.08981
#             KL (diag):  4.606e-03
#     Seed = 3:
#         Interpolation in training range:
#             Loglik (V): -1.443
#             KL (full):  0.1288
#             KL (diag):  0.05084
#         Interpolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.1315
#             KL (diag):  0.05349
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.08456
#             KL (diag):  -6.479e-04
#     Seed = 4:
#         Interpolation in training range:
#             Loglik (V): -1.413
#             KL (full):  0.09897
#             KL (diag):  0.02099
#         Interpolation beyond training range:
#             Loglik (V): -1.454
#             KL (full):  0.1396
#             KL (diag):  0.06161
#         Extrapolation beyond training range:
#             Loglik (V): -1.454
#             KL (full):  0.09519
#             KL (diag):  9.982e-03
#     Seed = 5:
#         Interpolation in training range:
#             Loglik (V): -1.443
#             KL (full):  0.1288
#             KL (diag):  0.05084
#         Interpolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.1301
#             KL (diag):  0.0521
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.08463
#             KL (diag):  -5.769e-04
#     Statistics over 5 replicates:
#         Interpolation in training range:
#             Loglik (V):   -1.43186 +-    0.01183
#             KL (full):     0.11788 +-    0.01183
#             KL (diag):     0.03991 +-    0.01183
#         Interpolation beyond training range:
#             Loglik (V):   -1.44701 +-    0.00327
#             KL (full):     0.13304 +-    0.00327
#             KL (diag):     0.05506 +-    0.00327
#         Extrapolation beyond training range:
#             Loglik (V):   -1.44688 +-    0.00370
#             KL (full):     0.08777 +-    0.00370
#             KL (diag):     0.00256 +-    0.00370
# Evaluate on rgnp:
#     Seed = 1:
#         Interpolation in training range:
#             Loglik (V): -1.392
#             KL (full):  0.07832
#             KL (diag):  3.455e-04
#         Interpolation beyond training range:
#             Loglik (V): -1.392
#             KL (full):  0.07832
#             KL (diag):  3.455e-04
#         Extrapolation beyond training range:
#             Loglik (V): -1.443
#             KL (full):  0.08361
#             KL (diag):  -1.594e-03
#     Seed = 2:
#         Interpolation in training range:
#             Loglik (V): -1.393
#             KL (full):  0.07865
#             KL (diag):  6.749e-04
#         Interpolation beyond training range:
#             Loglik (V): -1.393
#             KL (full):  0.07865
#             KL (diag):  6.749e-04
#         Extrapolation beyond training range:
#             Loglik (V): -1.442
#             KL (full):  0.08283
#             KL (diag):  -2.377e-03
#     Seed = 3:
#         Interpolation in training range:
#             Loglik (V): -1.393
#             KL (full):  0.07868
#             KL (diag):  7.060e-04
#         Interpolation beyond training range:
#             Loglik (V): -1.393
#             KL (full):  0.07868
#             KL (diag):  7.060e-04
#         Extrapolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.08542
#             KL (diag):  2.146e-04
#     Seed = 4:
#         Interpolation in training range:
#             Loglik (V): -1.393
#             KL (full):  0.07874
#             KL (diag):  7.709e-04
#         Interpolation beyond training range:
#             Loglik (V): -1.393
#             KL (full):  0.07874
#             KL (diag):  7.709e-04
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.08468
#             KL (diag):  -5.298e-04
#     Seed = 5:
#         Interpolation in training range:
#             Loglik (V): -1.392
#             KL (full):  0.07769
#             KL (diag):  -2.868e-04
#         Interpolation beyond training range:
#             Loglik (V): -1.392
#             KL (full):  0.07769
#             KL (diag):  -2.868e-04
#         Extrapolation beyond training range:
#             Loglik (V): -1.443
#             KL (full):  0.08437
#             KL (diag):  -8.364e-04
#     Statistics over 5 replicates:
#         Interpolation in training range:
#             Loglik (V):   -1.39239 +-    0.00034
#             KL (full):     0.07842 +-    0.00034
#             KL (diag):     0.00044 +-    0.00034
#         Interpolation beyond training range:
#             Loglik (V):   -1.39239 +-    0.00034
#             KL (full):     0.07842 +-    0.00034
#             KL (diag):     0.00044 +-    0.00034
#         Extrapolation beyond training range:
#             Loglik (V):   -1.44329 +-    0.00078
#             KL (full):     0.08418 +-    0.00078
#             KL (diag):    -0.00102 +-    0.00078

# %% [markdown]
# # dim_x = 5

# %%
model_list = ["cnp", "rcnp", "gnp", "rgnp"]  
num_replicates = 5
args['dim_x'] = 5
gens_eval = get_gen_eval(args, config)

for model_name in model_list:
    with out.Section(f"Evaluate on {model_name}"):
        # 3 datasets, 3 metrics, num_replicates data
        results = np.zeros((3, 3, num_replicates))
        for seed in range(1, 1+num_replicates):
            with out.Section(f"Seed = {seed}"):
                state = B.create_random_state(torch.float32, seed=seed)
                
                wd = get_dir(args, suffix, observe, seed, model_name, args.dim_x, args.dim_y)
                
                model = construct_model(model_name).to(device)
                name = "model-best.torch"
                model.load_state_dict(
                    torch.load(wd.file(name), map_location=device)["weights"]
                )

                for i, (gen_name, gen) in enumerate(gens_eval()):
                    with out.Section(gen_name.capitalize()):
                        state, results[i, 0, seed-1], results[i, 1, seed-1], results[i, 2, seed-1] = eval(state, model, objective_eval, gen)

        with out.Section(f"Statistics over {num_replicates} replicates"):
            for i, (gen_name, _) in enumerate(gens_eval()):
                with out.Section(gen_name.capitalize()):
                    out.kv("Loglik (V)", exp.with_err(results[i, 0]))
                    out.kv("KL (full)", exp.with_err(results[i, 1]))
                    out.kv("KL (diag)", exp.with_err(results[i, 2]))
# Out:
# Evaluate on cnp:
#     Seed = 1:
#         Interpolation in training range:
#             Loglik (V): -1.444
#             KL (full):  0.05697
#             KL (diag):  0.02219
#         Interpolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.05711
#             KL (diag):  0.02233
#         Extrapolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.03722
#             KL (diag):  3.132e-04
#     Seed = 2:
#         Interpolation in training range:
#             Loglik (V): -1.444
#             KL (full):  0.05696
#             KL (diag):  0.02218
#         Interpolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.05721
#             KL (diag):  0.02243
#         Extrapolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.03713
#             KL (diag):  2.242e-04
#     Seed = 3:
#         Interpolation in training range:
#             Loglik (V): -1.444
#             KL (full):  0.05697
#             KL (diag):  0.02218
#         Interpolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.05709
#             KL (diag):  0.02231
#         Extrapolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.03721
#             KL (diag):  2.991e-04
#     Seed = 4:
#         Interpolation in training range:
#             Loglik (V): -1.444
#             KL (full):  0.05697
#             KL (diag):  0.02218
#         Interpolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.05718
#             KL (diag):  0.0224
#         Extrapolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.03721
#             KL (diag):  3.043e-04
#     Seed = 5:
#         Interpolation in training range:
#             Loglik (V): -1.444
#             KL (full):  0.05697
#             KL (diag):  0.02219
#         Interpolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.05724
#             KL (diag):  0.02246
#         Extrapolation beyond training range:
#             Loglik (V): -1.445
#             KL (full):  0.03719
#             KL (diag):  2.832e-04
#     Statistics over 5 replicates:
#         Interpolation in training range:
#             Loglik (V):   -1.44438 +-    0.00000
#             KL (full):     0.05697 +-    0.00000
#             KL (diag):     0.02219 +-    0.00000
#         Interpolation beyond training range:
#             Loglik (V):   -1.44458 +-    0.00005
#             KL (full):     0.05717 +-    0.00005
#             KL (diag):     0.02238 +-    0.00005
#         Extrapolation beyond training range:
#             Loglik (V):   -1.44458 +-    0.00003
#             KL (full):     0.03719 +-    0.00003
#             KL (diag):     0.00028 +-    0.00003
# Evaluate on rcnp:
#     Seed = 1:
#         Interpolation in training range:
#             Loglik (V): -1.423
#             KL (full):  0.03563
#             KL (diag):  8.483e-04
#         Interpolation beyond training range:
#             Loglik (V): -1.423
#             KL (full):  0.03563
#             KL (diag):  8.483e-04
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.03696
#             KL (diag):  4.860e-05
#     Seed = 2:
#         Interpolation in training range:
#             Loglik (V): -1.423
#             KL (full):  0.03569
#             KL (diag):  9.074e-04
#         Interpolation beyond training range:
#             Loglik (V): -1.423
#             KL (full):  0.03569
#             KL (diag):  9.075e-04
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.03692
#             KL (diag):  7.389e-06
#     Seed = 3:
#         Interpolation in training range:
#             Loglik (V): -1.423
#             KL (full):  0.0356
#             KL (diag):  8.165e-04
#         Interpolation beyond training range:
#             Loglik (V): -1.423
#             KL (full):  0.0356
#             KL (diag):  8.165e-04
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.03695
#             KL (diag):  4.105e-05
#     Seed = 4:
#         Interpolation in training range:
#             Loglik (V): -1.423
#             KL (full):  0.03557
#             KL (diag):  7.891e-04
#         Interpolation beyond training range:
#             Loglik (V): -1.423
#             KL (full):  0.03557
#             KL (diag):  7.891e-04
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.03692
#             KL (diag):  1.039e-05
#     Seed = 5:
#         Interpolation in training range:
#             Loglik (V): -1.423
#             KL (full):  0.0356
#             KL (diag):  8.135e-04
#         Interpolation beyond training range:
#             Loglik (V): -1.423
#             KL (full):  0.0356
#             KL (diag):  8.135e-04
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.03691
#             KL (diag):  1.738e-06
#     Statistics over 5 replicates:
#         Interpolation in training range:
#             Loglik (V):   -1.42303 +-    0.00004
#             KL (full):     0.03562 +-    0.00004
#             KL (diag):     0.00083 +-    0.00004
#         Interpolation beyond training range:
#             Loglik (V):   -1.42303 +-    0.00004
#             KL (full):     0.03562 +-    0.00004
#             KL (diag):     0.00083 +-    0.00004
#         Extrapolation beyond training range:
#             Loglik (V):   -1.44431 +-    0.00002
#             KL (full):     0.03693 +-    0.00002
#             KL (diag):     0.00002 +-    0.00002
# Evaluate on gnp:
#     Seed = 1:
#         Interpolation in training range:
#             Loglik (V): -1.444
#             KL (full):  0.0567
#             KL (diag):  0.02192
#         Interpolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.05698
#             KL (diag):  0.0222
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.0367
#             KL (diag):  -2.110e-04
#     Seed = 2:
#         Interpolation in training range:
#             Loglik (V): -1.444
#             KL (full):  0.05672
#             KL (diag):  0.02193
#         Interpolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.05688
#             KL (diag):  0.0221
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.03674
#             KL (diag):  -1.698e-04
#     Seed = 3:
#         Interpolation in training range:
#             Loglik (V): -1.444
#             KL (full):  0.0567
#             KL (diag):  0.02192
#         Interpolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.05684
#             KL (diag):  0.02206
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.03675
#             KL (diag):  -1.628e-04
#     Seed = 4:
#         Interpolation in training range:
#             Loglik (V): -1.444
#             KL (full):  0.0567
#             KL (diag):  0.02192
#         Interpolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.05698
#             KL (diag):  0.02219
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.03675
#             KL (diag):  -1.589e-04
#     Seed = 5:
#         Interpolation in training range:
#             Loglik (V): -1.444
#             KL (full):  0.0567
#             KL (diag):  0.02192
#         Interpolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.05692
#             KL (diag):  0.02214
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.0367
#             KL (diag):  -2.073e-04
#     Statistics over 5 replicates:
#         Interpolation in training range:
#             Loglik (V):   -1.44412 +-    0.00001
#             KL (full):     0.05670 +-    0.00001
#             KL (diag):     0.02192 +-    0.00001
#         Interpolation beyond training range:
#             Loglik (V):   -1.44434 +-    0.00005
#             KL (full):     0.05692 +-    0.00005
#             KL (diag):     0.02214 +-    0.00005
#         Extrapolation beyond training range:
#             Loglik (V):   -1.44411 +-    0.00002
#             KL (full):     0.03673 +-    0.00002
#             KL (diag):    -0.00018 +-    0.00002
# Evaluate on rgnp:
#     Seed = 1:
#         Interpolation in training range:
#             Loglik (V): -1.423
#             KL (full):  0.03523
#             KL (diag):  4.432e-04
#         Interpolation beyond training range:
#             Loglik (V): -1.423
#             KL (full):  0.03523
#             KL (diag):  4.432e-04
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.03657
#             KL (diag):  -3.356e-04
#     Seed = 2:
#         Interpolation in training range:
#             Loglik (V): -1.423
#             KL (full):  0.03527
#             KL (diag):  4.918e-04
#         Interpolation beyond training range:
#             Loglik (V): -1.423
#             KL (full):  0.03527
#             KL (diag):  4.918e-04
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.03657
#             KL (diag):  -3.425e-04
#     Seed = 3:
#         Interpolation in training range:
#             Loglik (V): -1.423
#             KL (full):  0.03522
#             KL (diag):  4.388e-04
#         Interpolation beyond training range:
#             Loglik (V): -1.423
#             KL (full):  0.03522
#             KL (diag):  4.388e-04
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.03657
#             KL (diag):  -3.350e-04
#     Seed = 4:
#         Interpolation in training range:
#             Loglik (V): -1.423
#             KL (full):  0.03523
#             KL (diag):  4.481e-04
#         Interpolation beyond training range:
#             Loglik (V): -1.423
#             KL (full):  0.03523
#             KL (diag):  4.481e-04
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.03659
#             KL (diag):  -3.228e-04
#     Seed = 5:
#         Interpolation in training range:
#             Loglik (V): -1.423
#             KL (full):  0.03523
#             KL (diag):  4.525e-04
#         Interpolation beyond training range:
#             Loglik (V): -1.423
#             KL (full):  0.03523
#             KL (diag):  4.525e-04
#         Extrapolation beyond training range:
#             Loglik (V): -1.444
#             KL (full):  0.0366
#             KL (diag):  -3.055e-04
#     Statistics over 5 replicates:
#         Interpolation in training range:
#             Loglik (V):   -1.42265 +-    0.00002
#             KL (full):     0.03524 +-    0.00002
#             KL (diag):     0.00045 +-    0.00002
#         Interpolation beyond training range:
#             Loglik (V):   -1.42265 +-    0.00002
#             KL (full):     0.03524 +-    0.00002
#             KL (diag):     0.00045 +-    0.00002
#         Extrapolation beyond training range:
#             Loglik (V):   -1.44396 +-    0.00001
#             KL (full):     0.03658 +-    0.00001
#             KL (diag):    -0.00033 +-    0.00001
